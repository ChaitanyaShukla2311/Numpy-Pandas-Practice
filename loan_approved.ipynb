# %% [markdown]
# # problem statement

# %%
#predict loan status approved or not based on various features

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # read data

# %%
#load data
data=pd.read_csv("loan_approved.csv")
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Basic checks

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
data.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status (Approved)
# 609             1.0         Rural                      Y
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  601 non-null    object
#  2   Married                 611 non-null    object
#  3   Dependents              599 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           582 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              592 non-null    float64
#  9   Loan_Amount_Term        600 non-null    float64
#  10  Credit_History          564 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# i)there are total 614 rows and 13 columns
# ii)missing values are present in,
# Gender-13
# Married-3
# Dependents-15
# Self_Employed-32
# LoanAmount-22
# Loan_Amount_Term-14
# Credit_History-50

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#i)income shows high variability towards means
#ii)missing values are present in some features

# %% [markdown]
# # Domain Analaysis

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %% [markdown]
# Loan_ID :- loan Id number
#
# Gender :- Gender as male and female
#
# Married :- Marritial status as yes or no
#
# Dependents :-number of dependent
#
# Education :- graduate or not
#
# Self_Employed :- self employed as yes or no
#
# ApplicantIncome :- income of loan applicant
#
# CoapplicantIncome :- income of coapplicant
#
# LoanAmount  :- Amount of loan taken
#
# Loan_Amount_Term :- Term of loan to be paid in
#
# Credit_History :- previous credit history of loan
#
# Property_Area :- risk segmentation based on property area
#
# Loan_Status (Approved) :-Approved or Not Approved as Y and N

# %% [markdown]
# # Exploratory data analysis

# %%
#step 1: univariate analysis
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
sns.countplot(x='Gender',data=data)
#More male applicants than female.
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Married',data=data)
#most of applicant are married
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
col=data.columns[6:12]
plt.figure(figsize=(20,25),facecolor='white')
plotn=1
for column in col:
    if plotn<=5:
        ax=plt.subplot(3,2,plotn)
        sns.histplot(data[column],kde=True)
        
    plotn+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ApplicantIncome: Right-skewed, with a few high outliers.
# CoapplicantIncome : Mostly low; many entries are 0.
# LoanAmount: Concentrated around 100–200 range, with some outliers.
# Loan_Amount_Term: Majority have a term of 360 months.
# Credit_History: Mostly 1.0 (good credit history).

# %%
sns.countplot(x='Loan_Status (Approved)',data=data)
#most of loans applications are approved
# Out:
# <Axes: xlabel='Loan_Status (Approved)', ylabel='count'>

# %%
#step 2:-Bivariate analysis
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
col1=data.columns[1:6]
plt.figure(figsize=(20,25),facecolor='white')
plotn=1
for column in col1:
    if plotn<=5:
        ax=plt.subplot(3,2,plotn)
        sns.countplot(x=data[column],hue='Loan_Status (Approved)',data=data)
        
    plotn+=1
plt.tight_layout()
plt.show()

# %%
#i)Male,Married,Graduates,with 0 dependents are more likely to apply and get approved.

# %%
col=data.columns[6:12]
plt.figure(figsize=(20,25),facecolor='white')
plotn=1
for column in col:
    if plotn<=5:
        ax=plt.subplot(3,2,plotn)
        sns.boxplot(x='Loan_Status (Approved)',y=column,data=data)
        #sns.boxplot(x=data[column],hue='Loan_Status (Approved)',data=data)
        
    plotn+=1
plt.tight_layout()
plt.show()

# %%
#step 3:- multivariate analysis
sns.pairplot(data)

# %% [markdown]
# # Data preprocessing

# %%
data.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                    13
# Married                    3
# Dependents                15
# Education                  0
# Self_Employed             32
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                22
# Loan_Amount_Term          14
# Credit_History            50
# Property_Area              0
# Loan_Status (Approved)     0
# dtype: int64

# %%
#null values are there in Gender,Married,Dependents,Self_Employed ,LoanAmount ,Loan_Amount_Term and Credit_History

# %%
data.shape
# Out:
# (614, 13)

# %%
data.loc[data['Gender'].isnull()==True]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 23   LP001050    NaN     Yes          2  Not Graduate            No
# 126  LP001448    NaN     Yes         3+      Graduate            No
# 171  LP001585    NaN     Yes         3+      Graduate            No
# 188  LP001644    NaN     Yes          0      Graduate           Yes
# 314  LP002024    NaN     Yes          0      Graduate            No
# 334  LP002103    NaN     Yes          1      Graduate           Yes
# 460  LP002478    NaN     Yes          0      Graduate           Yes
# 467  LP002501    NaN     Yes          0      Graduate            No
# 477  LP002530    NaN     Yes          2      Graduate            No
# 507  LP002625    NaN      No          0      Graduate            No
# 576  LP002872    NaN     Yes          0      Graduate            No
# 588  LP002925    NaN      No          0      Graduate            No
# 592  LP002933    NaN      No         3+      Graduate           Yes
#
# ...

# %%
data.Gender.value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
#this is categorical column so replace null values with mode,so mode is male

# %%
data.loc[data.Gender.isnull()==True,'Gender']='Male'

# %%
data.Gender.isnull().sum()
# Out:
# 0

# %%
data.loc[data.Married.isnull()==True]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 104  LP001357    Male     NaN        NaN  Graduate            No
# 228  LP001760    Male     NaN        NaN  Graduate            No
# 435  LP002393  Female     NaN        NaN  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 104             3816              754.0       160.0             360.0
# 228             4758                0.0       158.0             480.0
# 435            10047                0.0         NaN             240.0
#
#      Credit_History Property_Area Loan_Status (Approved)
# 104             1.0         Urban                      Y
# 228             1.0     Semiurban                      Y
# 435             1.0     Semiurban                      Y

# %%
data.Married.value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
#this is categorical column so replace null values with mode,so mode is Yes

# %%
data.loc[data.Married.isnull()==True,'Married']='Yes'

# %%
data.Married.isnull().sum()
# Out:
# 0

# %%
data.loc[data.Dependents.isnull()==True]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 102  LP001350    Male     Yes        NaN      Graduate            No
# 104  LP001357    Male     Yes        NaN      Graduate            No
# 120  LP001426    Male     Yes        NaN      Graduate            No
# 226  LP001754    Male     Yes        NaN  Not Graduate           Yes
# 228  LP001760    Male     Yes        NaN      Graduate            No
# 293  LP001945  Female      No        NaN      Graduate            No
# 301  LP001972    Male     Yes        NaN  Not Graduate            No
# 332  LP002100    Male      No        NaN      Graduate            No
# 335  LP002106    Male     Yes        NaN      Graduate           Yes
# 346  LP002130    Male     Yes        NaN  Not Graduate            No
# 355  LP002144  Female      No        NaN      Graduate            No
# 435  LP002393  Female     Yes        NaN      Graduate            No
# 517  LP002682    Male     Yes        NaN  Not Graduate            No
# ...

# %%
data.Dependents.value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
sns.countplot(x='Dependents',data=data,hue='Loan_Status (Approved)')
plt.show()

# %%
# From the graphical representation it can be seen that as the number of dependents 
#getting increased,
# the chances of approval is less, since we have missed values and if we approve
# loan for them
# it can turn into major loss(high chance).Hence we will substitue missing values
#by 3+.
data.loc[data['Dependents'].isnull()==True,'Dependents']='3+'

# %%
data.Dependents.isnull().sum()
# Out:
# 0

# %%
data.loc[data.Self_Employed.isnull()==True]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 29   LP001087  Female      No          2      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 95   LP001326    Male      No          0      Graduate           NaN
# 107  LP001370    Male      No          0  Not Graduate           NaN
# 111  LP001387  Female     Yes          0      Graduate           NaN
# 114  LP001398    Male      No          0      Graduate           NaN
# 158  LP001546    Male      No          0      Graduate           NaN
# 170  LP001581    Male     Yes          0  Not Graduate           NaN
# 218  LP001732    Male     Yes          2      Graduate           NaN
# 231  LP001768    Male     Yes          0      Graduate           NaN
# ...

# %%
data.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
#since it is a categorical feature so we replace null with mode i.e. No

# %%
data.loc[data.Self_Employed.isnull()==True,'Self_Employed']='No'

# %%
data.Self_Employed.isnull().sum()
# Out:
# 0

# %%
data.loc[data.LoanAmount.isnull()==True]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 35   LP001106    Male     Yes          0      Graduate            No
# 63   LP001213    Male     Yes          1      Graduate            No
# 81   LP001266    Male     Yes          1      Graduate           Yes
# 95   LP001326    Male      No          0      Graduate            No
# 102  LP001350    Male     Yes         3+      Graduate            No
# 103  LP001356    Male     Yes          0      Graduate            No
# 113  LP001392  Female      No          1      Graduate           Yes
# 127  LP001449    Male      No          0      Graduate            No
# 202  LP001682    Male     Yes         3+  Not Graduate            No
# 284  LP001922    Male     Yes          0      Graduate            No
# 305  LP001990    Male      No          0  Not Graduate            No
# 322  LP002054    Male     Yes          2  Not Graduate            No
# ...

# %%
np.median(data.LoanAmount.dropna(axis=0))
# Out:
# 128.0

# %%
#we will replace null values with median which is 128.0

# %%
data.loc[data.LoanAmount.isnull()==True,'LoanAmount']=128.0

# %%
data.LoanAmount.isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                     0
# Married                    0
# Dependents                 0
# Education                  0
# Self_Employed              0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term          14
# Credit_History            50
# Property_Area              0
# Loan_Status (Approved)     0
# dtype: int64

# %%
data.loc[data.Loan_Amount_Term.isnull()==True]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 19   LP001041    Male     Yes          0      Graduate            No
# 36   LP001109    Male     Yes          0      Graduate            No
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
# 45   LP001137  Female      No          0      Graduate            No
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# 112  LP001391    Male     Yes          0  Not Graduate            No
# 165  LP001574    Male     Yes          0      Graduate            No
# 197  LP001669  Female      No          0  Not Graduate            No
# 223  LP001749    Male     Yes          0      Graduate            No
# 232  LP001770    Male      No          0  Not Graduate            No
# 335  LP002106    Male     Yes         3+      Graduate           Yes
# 367  LP002188    Male      No          0      Graduate            No
# 421  LP002357  Female      No          0  Not Graduate            No
# ...

# %%
# replace the null values in Loan_Amount_Term with the median value
data.loc[data['Loan_Amount_Term'].isnull()==True,'Loan_Amount_Term']=np.median(data.Loan_Amount_Term.dropna(axis=0))

# %%
data.Loan_Amount_Term.isnull().sum()
# Out:
# 0

# %%
data.loc[data.Credit_History.isnull()==True]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 16   LP001034    Male      No          1  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate            No
# 30   LP001091    Male     Yes          1      Graduate            No
# 42   LP001123    Male     Yes          0      Graduate            No
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 83   LP001273    Male     Yes          0      Graduate            No
# 86   LP001280    Male     Yes          2  Not Graduate            No
# 95   LP001326    Male      No          0      Graduate            No
# 117  LP001405    Male     Yes          1      Graduate            No
# 125  LP001443  Female      No          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 156  LP001541    Male     Yes          1      Graduate            No
# ...

# %%
data.Credit_History.value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
#replace null values with mode which is 1.0
data.loc[data.Credit_History.isnull()==True,'Credit_History']=1.0

# %%
data.isnull().sum()
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Property_Area             0
# Loan_Status (Approved)    0
# dtype: int64

# %%
#checking duplicate values
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  614 non-null    object
#  2   Married                 614 non-null    object
#  3   Dependents              614 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           614 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              614 non-null    float64
#  9   Loan_Amount_Term        614 non-null    float64
#  10  Credit_History          614 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
#we will use one-hot-encoding for labelling

# %%
df=pd.get_dummies(data['Gender'],prefix='Gender',dtype=int,drop_first=True)
data=pd.concat([data,df],axis=1).drop('Gender',axis=1)

# %%
df=pd.get_dummies(data['Married'],prefix='Married',dtype=int,drop_first=True)
data=pd.concat([data,df],axis=1).drop('Married',axis=1)

# %%
df=pd.get_dummies(data['Dependents'],prefix='Dependents',dtype=int,drop_first=True)
data=pd.concat([data,df],axis=1).drop('Dependents',axis=1)

# %%
df=pd.get_dummies(data['Education'],prefix='Education',dtype=int,drop_first=True)
data=pd.concat([data,df],axis=1).drop('Education',axis=1)

# %%
df=pd.get_dummies(data['Self_Employed'],prefix='Self_Employed',dtype=int,drop_first=True)
data=pd.concat([data,df],axis=1).drop('Self_Employed',axis=1)

# %%
df=pd.get_dummies(data['Property_Area'],prefix='Property_Area',dtype=int,drop_first=True)
data=pd.concat([data,df],axis=1).drop('Property_Area',axis=1)

# %%
#we will use manual encoding for target column
data.rename(columns={'Loan_Status (Approved)':'Loan_Status'},inplace=True)
data.Loan_Status=data.Loan_Status.map({'Y':1,'N':0})

# %%
data
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0       128.0
# 1    LP001003             4583             1508.0       128.0
# 2    LP001005             3000                0.0        66.0
# 3    LP001006             2583             2358.0       120.0
# 4    LP001008             6000                0.0       141.0
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0        71.0
# 610  LP002979             4106                0.0        40.0
# 611  LP002983             8072              240.0       253.0
# 612  LP002984             7583                0.0       187.0
# 613  LP002990             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History  Loan_Status  Gender_Male  Married_Yes  \
# 0               360.0             1.0            1            1            0
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History  Loan_Status  Gender_Male  Married_Yes  Dependents_1  \
# count      614.000000   614.000000   614.000000   614.000000    614.000000
# mean         0.855049     0.687296     0.817590     0.653094      0.166124
# std          0.352339     0.463973     0.386497     0.476373      0.372495
# ...

# %%
#handling Outliers
cols=['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term']
for i in cols:
    Q1=data[i].quantile(0.25)
    Q3=data[i].quantile(0.75)
    IQR=Q3-Q1
    lower=Q1-1.5*IQR
    upper=Q3+1.5*IQR
    data.loc[data[i]<lower,i]=np.median(data[i])
    data.loc[data[i]>upper,i]=np.median(data[i])

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotn=1
for column in cols:
    if plotn<=5:
        ax=plt.subplot(3,2,plotn)
        sns.boxplot(x='Loan_Status',y=column,data=data)
        #sns.boxplot(x=data[column],hue='Loan_Status (Approved)',data=data)
        
    plotn+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Selection

# %%
data.drop('Loan_ID',axis=1,inplace=True)

# %%
#droped unnecessary column

# %%
plt.figure(figsize=(20,25),facecolor='white')
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
#there is no column having higher correlation

# %%
X=data.drop('Loan_Status',axis=1)
y=data.Loan_Status

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42)

# %% [markdown]
# # Model creation

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,classification_report,f1_score
acc=accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7727272727272727

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.39      0.55        54
#            1       0.75      0.98      0.85       100
#
#     accuracy                           0.77       154
#    macro avg       0.83      0.68      0.70       154
# weighted avg       0.81      0.77      0.74       154

# %%
f1=f1_score(y_test,y_pred)
f1
# Out:
# 0.8484848484848485

# %%
from sklearn.metrics import roc_curve,auc
false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,y_pred)
roc_auc_score=auc(false_positive_rate,true_positive_rate)
print(roc_auc_score)
# Out:
# 0.6844444444444444

# %%
#it is greater than 0.5 so model is working well

# %% [markdown]
# # final conclusion

# %%
#In this project, we aimed to build a machine learning model that predicts whether a loan will be approved or not 
#based on applicant features such as gender, income, credit history, and loan amount.

# %%
#The logistic model achieved the accuracy of **77.28%** on the test set. 
#This suggests that the model can reasonably predict loan approvals based on input features.

# %%
#Business Insight:
#The model can assist loan officers in pre-screening applications by flagging high-risk applicants, improving efficiency and reducing defaults.
